# %%
import pandas as pd
import seaborn as sns

# %%
pd = pd.read_csv(' /content/titanic ds.csv')
print("Dataset data:")
print(pd)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4309/997099366.py in <cell line: 0>()
# ----> 1 pd = pd.read_csv(' /content/titanic ds.csv')
#       2 print("Dataset data:")
#       3 print(pd)
#
# ...

# %%
print("First 5 values of Dataframe: ")
Print(pd.head()
# Out:
# First 5 values of Dataframe:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4309/2112717134.py in <cell line: 0>()
#       1 print("First 5 values of Dataframe: ")
# ----> 2 pd.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
print("Last 5 values of Dataframe: ")
pd.tail()

# %%
print("Total null values in dataset: ")
pd.isnull().sum().sum()

# %%
print("Basic Statistical data of DataFrame: ")
pd.describe()

# %%
print("Random 15 values from DataFrame")
pd.sample(15)

# %%
print("Total number of records in dataframe(total number of cells): ")
pd.size

# %%
print("Number of Rows and columns in the dataframe: ")
pd.shape
#pd.shape[0] for columns
#pd.shape[1] for rows

# %%
pd.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4309/3759477352.py in <cell line: 0>()
# ----> 1 pd.info()
#
# AttributeError: module 'pandas' has no attribute 'info'

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived", hue='Sex',data=pd)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4309/3877411473.py in <cell line: 0>()
#       1 sns.set_style("whitegrid")
# ----> 2 sns.countplot(x="Survived", hue='Sex',data=pd)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ...

# %%
pd.quantile(0.25)
pd.quantile(0.50)
pd.quantile(0.75)
pd.quantile(1)
